# %%
import networkx as nx
import osmnx as ox

ox.__version__


# download/model a street network for some city then visualize it
G = ox.graph_from_place("Piedmont, California, USA", network_type="drive")
fig, ax = ox.plot_graph(G)

# %%
# convert your MultiDiGraph to an undirected MultiGraph
M = ox.utils_graph.get_undirected(G)

# convert your MultiDiGraph to a DiGraph without parallel edges
D = ox.utils_graph.get_digraph(G)

print(D)
# Out:
# DiGraph with 353 nodes and 939 edges

# %%
# you can convert your graph to node and edge GeoPandas GeoDataFrames
gdf_nodes, gdf_edges = ox.graph_to_gdfs(G)
gdf_nodes.head()
gdf_edges.head()

print(gdf_nodes.head())
# Out:
#                   y           x  street_count highway  \
# osmid
# 53017091  37.826250 -122.247604             3     NaN
# 53018397  37.824224 -122.247194             3     NaN
# 53018399  37.824900 -122.246113             3     NaN
# 53018402  37.825406 -122.245338             3     NaN
# 53018404  37.825948 -122.244467             3     NaN
#
#                              geometry
# osmid
# 53017091  POINT (-122.24760 37.82625)
# 53018397  POINT (-122.24719 37.82422)
# 53018399  POINT (-122.24611 37.82490)
# 53018402  POINT (-122.24534 37.82541)
# 53018404  POINT (-122.24447 37.82595)

# %%
# what sized area does our network cover in square meters?
G_proj = ox.project_graph(G)
nodes_proj = ox.graph_to_gdfs(G_proj, edges=False)
graph_area_m = nodes_proj.unary_union.convex_hull.area
graph_area_m

ox.basic_stats(G_proj, area=graph_area_m, clean_int_tol=15)
# Out:
# {'n': 353,
#  'm': 948,
#  'k_avg': 5.371104815864022,
#  'edge_length_total': 112028.821,
#  'edge_length_avg': 118.17386181434598,
#  'streets_per_node_avg': 2.951841359773371,
#  'streets_per_node_counts': {0: 0, 1: 34, 2: 0, 3: 270, 4: 47, 5: 2},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.09631728045325778,
#   2: 0.0,
#   3: 0.7648725212464589,
#   4: 0.13314447592067988,
#   5: 0.0056657223796034},
#  'intersection_count': 319,
#  'street_length_total': 58076.252,
#  'street_segment_count': 497,
#  'street_length_avg': 116.85362575452716,
#  'circuity_avg': 1.1111605002201332,
#  'self_loop_proportion': 0.006036217303822937,
#  'clean_intersection_count': 267,
#  'node_density_km': 84.06195830904933,
#  'intersection_density_km': 75.96533909514656,
#  'edge_density_km': 26678.079547631583,
#  'street_density_km': 13830.038171019385,
#  'clean_intersection_density_km': 63.58227441505997}

# %%
import requests

def get_elevation_open_elevation(lat, lon):
    base_url = "https://api.open-elevation.com/api/v1/lookup"
    params = {
        "locations": f"{lat},{lon}",
    }

    response = requests.get(base_url, params=params)
    data = response.json()

    if "results" in data and data["results"]:
        elevation = data["results"][0]["elevation"]
        return elevation
    else:
        return None

# Example usage
latitude = 37.7749  # Replace with the desired latitude
longitude = -122.4194  # Replace with the desired longitude

elevation = get_elevation_open_elevation(latitude, longitude)
print(f"Elevation: {elevation} meters")


# print(G.nodes(data=True))
print(G)

# Add elevation data to nodes
for node, data in G.nodes(data=True):
    elevation = get_elevation_open_elevation(data['y'], data['x'])
    data['elevation'] = elevation

print("elevation added")

# G = ox.elevation.add_node_elevations_google(G, api_key=google_elevation_api_key)
G = ox.elevation.add_edge_grades(G)
nc = ox.plot.get_node_colors_by_attr(G, "elevation", cmap="plasma")
fig, ax = ox.plot_graph(G, node_color=nc, node_size=20, edge_linewidth=2, edge_color="#333")
print("done")
# Out:
# Elevation: 16.0 meters
# MultiDiGraph with 353 nodes and 948 edges
# elevation added
# done

# %%
import osmnx as ox
import requests
import pandas as pd
import requests


def get_elevation_open_elevation(lat, lon):
    base_url = "http://localhost:443/api/v1/lookup?"
    params = {
        "locations": f"{lat},{lon}",
    }

    response = requests.get(base_url, params=params)
    data = response.json() if response is not None and response.content else None
    if 'results' in data and data['results']:
        elevation = data['results'][0]['elevation']
    return elevation

    # if 'highway' in data.tags:
    #     if data.tags['highway'] in ['motorway', 'motorway_link', 'trunk', 'trunk_link']:
    #         return False  # Exclude highways where walking or biking is not allowed
    # elif 'railway' in data.tags:
    #     return False  # Exclude railways (subways/trains)
    # elif 'amenity' in data.tags and data.tags['amenity'] == 'parking':
    #     return False  # Exclude parking lots
    # elif 'foot' in data.tags and data.tags['foot'] == 'no':
    #     return False  # Exclude roads where walking is not allowed
    # elif 'bicycle' in data.tags and data.tags['bicycle'] == 'no':
    #     return False  # Exclude roads where biking is not allowed
    # return True


custom_filter ='["bicycle"!~"no"]["foot"!~"no"]["building"!~"."]["amenity"!~"parking"]["railway"!~"."]'


# Specify the place name for North Rhine-Westphalia, Germany
place_name = "Dortmund, North-Rhine Westphalia, Germany"
print("start")

# Create the graph for NRW
G = ox.graph_from_place(place_name, network_type='all')
print(G)
# G = ox.graph_from_place(place_name, network_type='all', custom_filter = custom_filter)
# print(G)

# Add elevation data to nodes
for node, data in G.nodes(data=True):

    elevation = get_elevation_open_elevation(data['y'], data['x'])
    # data['elevation'] = elevation  
    if elevation is not None:
        data['elevation'] = elevation
    else:
        print(f"Failed to retrieve elevation data for node {node}")

print("elevation")


# Convert the graph data to pandas DataFrames
df_nodes, df_edges = ox.graph_to_gdfs(G)
print("convert")
print(df_nodes)


# Save the DataFrames to CSV files
df_nodes.to_csv('nodes_nrw.csv', index=False)
df_edges.to_csv('edges_nrw.csv', index=False)


G = ox.elevation.add_edge_grades(G)
nc = ox.plot.get_node_colors_by_attr(G, "elevation", cmap="plasma")
fig, ax = ox.plot_graph(G, node_color=nc, node_size=20, edge_linewidth=2, edge_color="#333")

print("done")
# Out:
# start
# MultiDiGraph with 111460 nodes and 295037 edges
# MultiDiGraph with 186331 nodes and 610809 edges
# elevation
# convert
#                      y         x  street_count  elevation   highway  ref  \
# osmid
# 160374       51.489412  7.405439             4        134       NaN  NaN
# 160375       51.490010  7.410145             3        122       NaN  NaN
# 160376       51.487569  7.410966             4        123       NaN  NaN
# 160379       51.486375  7.404469             4        133  crossing  NaN
# 160380       51.485649  7.402769             4        137       NaN  NaN
# ...                ...       ...           ...        ...       ...  ...
# 11663797964  51.508926  7.503678             3        106       NaN  NaN
# 11663797966  51.509076  7.502991             1        106       NaN  NaN
# 11667556784  51.486966  7.513539             1        113       NaN  NaN
# 11667556791  51.486860  7.513142             4        113       NaN  NaN
# 11667556792  51.486782  7.513111             3        113       NaN  NaN
#
#                              geometry
# osmid
# 160374       POINT (7.40544 51.48941)
# 160375       POINT (7.41014 51.49001)
# 160376       POINT (7.41097 51.48757)
# 160379       POINT (7.40447 51.48637)
# 160380       POINT (7.40277 51.48565)
# ...                               ...
# 11663797964  POINT (7.50368 51.50893)
# 11663797966  POINT (7.50299 51.50908)
# 11667556784  POINT (7.51354 51.48697)
# 11667556791  POINT (7.51314 51.48686)
# 11667556792  POINT (7.51311 51.48678)
#
# [186331 rows x 7 columns]
# done

# %%
# !pip install pyodbc

# %%
import pyodbc
import hashlib
import uuid

# Establish connection to SQL Server
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=localhost\\SQLEXPRESS;'
                      'Database=GridDataDB;'
                      'Trusted_Connection=yes;')
cursor = conn.cursor()


def create_table_node():
    cursor.execute('''
		CREATE TABLE Node (
            Id UNIQUEIDENTIFIER PRIMARY KEY,
            GeographyValues GEOGRAPHY,
            Elevation INT
            )
                ''')

def create_table_edge():
    cursor.execute('''
		CREATE TABLE Edge (
            Id UNIQUEIDENTIFIER PRIMARY KEY,
            ShoelaceForward DECIMAL(18, 0),
            ShoelaceBackward DECIMAL(18, 0),
            Tags TEXT,
            GeoLocations GEOGRAPHY,
            SourceNodeId UNIQUEIDENTIFIER FOREIGN KEY REFERENCES Edge(Id),
            TargetNodeId UNIQUEIDENTIFIER FOREIGN KEY REFERENCES Edge(Id),
            Reversed BIT NULL,
            Cost DECIMAL(18, 0),
            OneWay BIT NULL            
			)
               ''')

def create_table_incident_edges():
     cursor.execute('''
        CREATE TABLE IncidentEdges (
            node_id UNIQUEIDENTIFIER,
            edge_id UNIQUEIDENTIFIER,
            NodeId UNIQUEIDENTIFIER FOREIGN KEY REFERENCES Nodes(Id),
            EdgeId UNIQUEIDENTIFIER FOREIGN KEY REFERENCES Edges(Id),
            PRIMARY KEY (NodeId, EdgeId)
        )
    ''')

def check_id_exists(cursor, node_id, table_name):
    cursor.execute("SELECT COUNT(*) FROM " + table_name + " WHERE Id = ?", node_id)
    count = cursor.fetchone()[0]
    return count > 0

def check_ids_exist(cursor, id1, id2, table_name):
    cursor.execute("SELECT COUNT(*) FROM " + table_name + " WHERE NodeId = ? AND EdgeId = ?", (id1, id2))
    count = cursor.fetchone()[0]
    return count > 0


def generate_id(osmid_tuple):
    if isinstance(osmid_tuple, int):
        int_bytes = osmid_tuple.to_bytes((osmid_tuple.bit_length() + 7) // 8, byteorder='big', signed=False)
        sha256_digest = hashlib.sha256(int_bytes).digest()
        uuid_bytes = sha256_digest[:16]
        return uuid.UUID(int=osmid_tuple)
    else:
        osmid_str = ','.join(str(osmid) for osmid in sorted(osmid_tuple)).encode()
        sha256_digest = hashlib.sha256(osmid_str).digest()
        edge_uuid = uuid.UUID(bytes=sha256_digest[:16])  # Convert the first 16 bytes to UUID
        return edge_uuid
    

# Query to get all tables
tables = cursor.execute("SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_TYPE = 'BASE TABLE'")

# Fetch all table names
table_names = [table[0] for table in tables.fetchall()]

# Print the list of table names
if table_names == []:
    print('Table not found!')
    create_table_node()
    create_table_edge()
    create_table_incident_edges()
    print("create all")
else:
    if "Edge" not in table_names:
        create_table_edge()
        print("edge")
    if "Node" not in table_names:
        crate_table_node()
        print("node")
    if "IncidentEdges" not in table_names:
        create_table_incident_edges()
        print("incident edges")
    

print("done")

nodes = list(G.nodes(data=True))
edges = list(G.edges(data=True))


# Insert node data into the Nodes table
cursor = conn.cursor()
for node in nodes:
    node_id = generate_id(node[0]) # Generate a new UUID for each node
    if not check_id_exists(cursor, node_id, "Node"):
        point = f"POINT({node[1]['x']} {node[1]['y']})"
        cursor.execute('''
            INSERT INTO Node (Id, GeographyValues, Elevation)
            VALUES (?, geography::STGeomFromText(?, 4326), ?)
        ''', (node_id, point, node[1].get('elevation', None)))

print("commit nodes")
conn.commit()


# Insert edge data into the Edges table
for source_node_id, target_node_id, edge_attrs in edges:
    edge_id = generate_id(edge_attrs.get('osmid',None))
    source_node_id = generate_id(source_node_id)
    target_node_id = generate_id(target_node_id)
    # edge_id = generate_edge_id(edge_id)
    # print(edge_attrs.get('geometry'))
    # print(edge_attrs)
    highway_tags = edge_attrs.get('highway', [])
    if not check_id_exists(cursor, edge_id, "Edge"):
        cursor.execute('''
            INSERT INTO Edge (Id, SourceNodeId, TargetNodeId, Cost, Tags, Oneway, Reversed)
            VALUES (?, ?, ?, ?, ?, ?, ?)
        ''', (
        edge_id,
        source_node_id,
        target_node_id,
        edge_attrs.get('length', None),
        ', '.join(highway_tags) 
          if (isinstance(highway_tags, list) and 
                    all(isinstance(item, str) and 
                        len(item) > 1 for item in highway_tags)) 
              else highway_tags,
        1 if edge_attrs.get('oneway', None) else 0, 
        1 if edge_attrs.get('reversed', None) else 0
        ))
    
    if edge_attrs.get('geometry') is not None:
        geolocations = edge_attrs.get('geometry')
        if isinstance(geolocations, str):
            # Convert WKT string to binary using STGeomFromText
            cursor.execute('''
                UPDATE Edge
                SET GeoLocations = geography::STGeomFromText(?, 4326)
                WHERE Id = ?
            ''', (geolocations, edge_id))
        else:
            # Convert WKT representation of geometry to binary using STGeomFromText
            cursor.execute('''
                UPDATE Edge
                SET GeoLocations = geography::STGeomFromText(?, 4326)
                WHERE Id = ?
            ''', (geolocations.wkt, edge_id))

    
    if not check_ids_exist(cursor, source_node_id, edge_id, "IncidentEdges"):
        cursor.execute('''
            INSERT INTO IncidentEdges (NodeId, edgeId)
            VALUES (?, ?)
        ''', (source_node_id, edge_id))
    if not check_ids_exist(cursor, target_node_id, edge_id, "IncidentEdges"):
        cursor.execute('''
            INSERT INTO IncidentEdges (NodeId, edgeId)
            VALUES (?, ?)
        ''', (target_node_id, edge_id))
conn.commit()
print("commit edges")

# Close the cursor and connection
cursor.close()
conn.close()
print("all done")
# Out:
# done
# commit nodes
# residential
# tertiary
# residential
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
# footway
# footway
# tertiary
# secondary
# secondary
# secondary
# secondary
# residential
# secondary
# tertiary
# motorway_link
# motorway
#
# motorway
#
#
# motorway
#
# secondary
# residential
# secondary
# residential
# secondary
# secondary
# residential
# secondary
# secondary
# secondary
# secondary
# motorway
# motorway
#
#
#
# motorway_link
#
# motorway_link
#
#
# motorway_link
# motorway
# motorway_link
# motorway_link
# motorway
# motorway
# motorway_link
# secondary
# secondary
# secondary
# residential
# tertiary
# residential
# tertiary
# motorway_link
# motorway_link
# trunk, primary
#
#
# primary_link
# residential
# residential
# footway
# service
# residential
# residential
# service
# residential
# residential
# service
# service
# service
# service
# service
# service
#
# trunk
#
#
#
# trunk
#
#
# trunk
# trunk
# trunk_link
# motorway_link
# motorway_link
# motorway_link
# motorway
#
# motorway
#
# motorway
#
# motorway_link
#
# residential
# tertiary
# tertiary
# residential
# residential
# living_street
# footway
# residential
# residential
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
# residential
# tertiary
# secondary
# secondary
# secondary
# tertiary
# motorway_link
# trunk_link
# trunk
# trunk
#
#
#
# trunk
#
#
# trunk
#
# trunk_link
# trunk
# secondary
# residential
# secondary
# secondary
# secondary
# secondary
# service
# secondary
#
#
# secondary
#
#
# secondary
# secondary
# cycleway
# secondary
# path
# secondary_link
# secondary
# secondary
# secondary
#
#
# secondary
#
# secondary
#
#
#
# secondary
#
# secondary
#
# track
# secondary
#
# secondary
#
#
# secondary
#
# secondary
# secondary
# secondary
# secondary
# path
# residential
# secondary
# secondary
#
# secondary
#
# secondary
#
# secondary
#
# secondary
#
#
# secondary
#
#
# secondary
#
#
# secondary
#
#
# secondary
#
#
# secondary
#
#
# secondary
#
#
# secondary
#
#
# footway
# secondary
# secondary
# footway
# secondary
# residential
# secondary
# path
# secondary
# secondary
# service
# secondary
# primary
# primary
# primary
# primary
# primary
# motorway_link
# motorway_link
# motorway_link
# motorway_link
# primary
# motorway_link
# primary
#
#
# primary
# primary
#
#
#
#
#
#
#
#
#
#
#
#
# primary
# service
# primary
# service
# primary
# service
# primary
# primary
# primary
#
#
# primary
# footway
# primary
# primary
# footway
# secondary
# cycleway
# secondary
# cycleway, footway
# tertiary
# tertiary
# service
# tertiary
# tertiary
# unclassified
# tertiary
# tertiary
# unclassified
# tertiary
# service
# tertiary
# residential
# secondary
# residential
# secondary
# footway
# footway
# secondary
# secondary
# residential
# residential
# secondary
# secondary
# residential
# secondary
# secondary
# residential
# secondary
# secondary
# residential
# secondary
# secondary
# residential
# secondary
# secondary
# residential
# residential
# secondary
# secondary
# residential
# secondary
# secondary
# secondary
# secondary
# service
# secondary
# secondary
# secondary
# service
# secondary
# secondary
# residential
#
#
# secondary
# secondary
# secondary
# footway
# footway
# secondary
# secondary
# secondary
# residential
# secondary
# secondary
# secondary
# service
# secondary
# service
# secondary
# secondary
# secondary
# residential
# secondary
# service
# secondary
# footway
# secondary
# footway
#
#
#
#
#
#
#
#
# tertiary
# residential
# tertiary
# tertiary
# tertiary
# secondary
# secondary
# tertiary
# secondary
# tertiary
# secondary
# residential
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# footway
# residential
# residential
# residential
# tertiary
# tertiary
# cycleway, path
# cycleway, path
# tertiary
# tertiary
# tertiary
# tertiary
# cycleway
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
# unclassified
#
#
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# service
# tertiary
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
# tertiary
#
#
# tertiary
#
# tertiary
#
# tertiary
#
# tertiary
#
#
# tertiary
#
# tertiary
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
#
# tertiary
#
#
# tertiary
#
# tertiary
#
#
#
# primary
# cycleway
# tertiary
#
# primary
# primary
# primary
# track
# primary
# primary
# secondary
#
#
# secondary
# secondary
#
#
# secondary
#
#
# secondary
#
#
# secondary
#
#
# secondary
#
#
# secondary
# cycleway
#
#
# cycleway
#
#
# tertiary
#
# tertiary
#
#
#
# tertiary
#
#
# tertiary
# tertiary
# tertiary
# footway
# footway
# trunk_link
# path
# secondary
# secondary
# service
# secondary
# secondary
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
# service
# unclassified
# tertiary
# tertiary
# unclassified
# tertiary
# tertiary
# unclassified
# tertiary
# tertiary
# tertiary
# tertiary
# service
# tertiary
# unclassified
# unclassified
# tertiary
# tertiary
# tertiary
# footway
# footway
# motorway
#
#
# motorway
# service
#
#
#
# motorway
#
# motorway_link
#
#
# motorway
#
#
# residential
# trunk
# secondary
# primary
# unclassified
# primary
# footway
# footway
# primary
# residential
# primary
# unclassified
# unclassified
# residential
# primary
# residential
# primary
# secondary
# primary
# footway
# primary
# footway
# primary
# residential
# footway
# primary
# path
# secondary
# primary
# cycleway
# primary
# tertiary
# residential
# residential
# primary
# residential
# primary
# residential
# primary
# residential
# primary
# tertiary
# residential
# primary
# primary
# primary
#
#
# primary
# primary
#
#
# primary
# secondary
# primary
# primary
# primary
# secondary_link
# primary
# primary
# trunk_link
# primary
# service
# trunk_link
# primary
# primary
# primary
# primary
# primary_link
# primary
# secondary
# secondary
# secondary_link
# secondary
# secondary
# unclassified
# secondary
# secondary
# secondary
# unclassified
# secondary
# secondary
# secondary
# secondary
# secondary
# residential
#
# secondary
# unclassified
# secondary
#
#
# secondary
#
# trunk
#
# trunk
# trunk_link
# trunk
#
#
# trunk
#
#
# trunk_link
# trunk
#
#
# trunk
#
#
# trunk
#
#
# trunk
#
#
# trunk
# trunk
#
#
#
#
# trunk
# trunk_link
# trunk
# trunk_link
# trunk_link
# trunk_link
# trunk_link
# secondary
# secondary
# secondary
# secondary
# residential
# residential
# secondary
# tertiary
# residential
# tertiary
# tertiary
# tertiary
# footway
# footway
# secondary
# tertiary
# tertiary
# tertiary
# tertiary
# footway
# footway
# residential
# tertiary
# tertiary
# primary
# primary
# residential
# primary
# path
# path
# primary
# primary
# primary
# residential
# residential
# residential
# residential
# residential
# pedestrian
# pedestrian
# pedestrian
# primary
# footway
# footway
# primary_link
# primary
# primary
# primary
# residential
# primary
# primary
# footway
# footway
# residential
# primary
# primary
#
#
# primary
# residential
# primary
# residential
# residential
# unclassified
# primary
# primary
# tertiary
# primary
# footway
# primary
# footway
# path
# primary
# footway
# primary
#
# primary
#
# footway
#
#
#
#
#
# primary
#
# primary
#
# primary
#
# primary
#
# primary
#
# primary
# residential
# primary
# primary
# residential
# cycleway
# primary
# primary
# cycleway, footway
# tertiary
# secondary
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# service
# secondary
# secondary
# secondary
# footway
# footway
# secondary
# residential
# secondary
# secondary
# secondary
# secondary
# service
# residential
# secondary
# secondary
# residential
# secondary
# secondary
# tertiary
# residential
# secondary
# secondary
# tertiary
# tertiary
# residential
# tertiary
# tertiary
# residential
# tertiary
# tertiary
#
# secondary
#
#
#
# secondary
#
#
#
# secondary
#
# secondary
#
# secondary
#
# secondary
# secondary
#
#
# secondary
# secondary
# secondary
# path
# secondary
# track
# secondary
#
# secondary
#
# secondary
# secondary
# secondary
# secondary
# service
# secondary
# secondary
# service
# secondary
# secondary
# secondary_link
# secondary
# residential
# residential
# secondary
# secondary
# secondary
#
#
# secondary
#
#
# secondary
# secondary
# secondary
#
# secondary
#
# secondary_link
# secondary
#
#
#
#
# secondary
#
#
# footway
# footway
#
#
#
#
# secondary
#
#
#
#
# secondary
# secondary
#
#
# secondary
#
#
# secondary
#
#
# secondary
#
#
# secondary
# secondary
# secondary
# secondary
# footway
# footway
# residential
#
#
#
# residential
#
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# service
# residential
# residential
# residential
# secondary
# residential
# secondary
# secondary
#
#
# secondary
# motorway_link
# secondary
# secondary
# tertiary
# motorway_link
# motorway
#
# motorway_link
#
# primary
# residential
# residential
# service
# residential
# residential
# service
# tertiary
# tertiary
# residential
# secondary
# secondary
# cycleway
# secondary
# secondary
# service
# residential
# secondary
# secondary
# secondary
# tertiary
# secondary
# cycleway
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# service
# secondary
# secondary
# secondary
# residential
# secondary
# secondary
# path
# secondary
# secondary
# secondary
# secondary
# secondary
# footway
# footway
# secondary
# residential
# footway
# secondary
# secondary
# secondary
# secondary
# footway
# footway
# tertiary
# secondary
# secondary
# residential
# residential
# tertiary
# tertiary
# tertiary
# service
# tertiary
# tertiary
# tertiary
# service
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
# service
# tertiary
# tertiary
# service
# tertiary
# tertiary
# service
# footway
# footway
# tertiary
# tertiary
# tertiary
# tertiary
# secondary
# secondary
# secondary
# footway
# footway
# secondary
# secondary_link
# secondary
# residential
# residential
# footway
# residential
# residential
# footway
# residential
# residential
# footway
# footway
# residential
# residential
# tertiary
# residential
# tertiary
# service
# tertiary
# tertiary
# tertiary
# path
# tertiary
# tertiary
# tertiary
# footway
# footway
# tertiary
# tertiary
# service
# residential
# tertiary
# tertiary
# residential
# tertiary
# tertiary
# tertiary
# tertiary
# residential
# service
# tertiary
#
# tertiary
# tertiary
#
# tertiary
#
# tertiary
#
# tertiary
#
# tertiary
#
# tertiary
# tertiary
#
#
# tertiary
#
# tertiary
#
#
#
# tertiary
#
#
# tertiary
#
# tertiary
#
# tertiary
#
#
# tertiary
#
# tertiary
# service
#
#
# tertiary
#
# tertiary
#
#
#
# tertiary
#
# tertiary
#
#
# tertiary
#
# tertiary
#
#
#
#
#
# tertiary
# tertiary
# secondary
# secondary
# tertiary
# residential
#
#
# secondary
# secondary
#
#
# secondary
#
#
# secondary
# unclassified
#
#
#
#
# secondary
#
#
# secondary
# secondary
#
# secondary
#
# tertiary
#
#
# secondary
# secondary
# secondary
# track
# secondary
# secondary
# residential
#
#
#
#
# residential
# residential
#
#
#
# residential
#
# residential
# residential
# path
# secondary
# secondary
# secondary
# secondary
# cycleway
# service
# secondary
# cycleway
# tertiary
# secondary
# service
# secondary
# secondary
# tertiary
# tertiary
# residential
# tertiary
#
# tertiary
#
# tertiary
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
# tertiary
# service
# tertiary
# tertiary
# residential
# motorway_link
# motorway_link
#
#
# trunk
# trunk
#
#
# motorway_link
# motorway_link
#
# motorway_link
#
#
# motorway
#
#
# motorway
#
# motorway_link
# motorway
# motorway_link
#
#
# motorway
#
#
# motorway
#
#
# motorway
#
#
# motorway
#
#
#
#
# motorway
# motorway
#
#
#
#
# motorway
# motorway_link
# motorway
# motorway_link
# motorway_link
#
#
# motorway
# motorway
#
#
#
#
# motorway
# motorway
#
#
# motorway
#
#
#
#
# motorway
# motorway
#
#
#
#
# motorway
# motorway
#
#
# motorway
# motorway_link
# motorway
# motorway
#
#
#
# motorway
#
#
# motorway
#
#
# motorway
#
# motorway
#
#
# motorway
#
#
#
# motorway
#
#
# motorway
#
#
# motorway
#
#
# motorway
#
#
# motorway
#
#
#
# trunk_link
# trunk_link, trunk
# trunk
# trunk
# trunk_link
# trunk
#
#
# trunk_link
#
#
# trunk_link
# trunk_link
# tertiary
# secondary
# secondary
# service
# secondary
# secondary
# footway
# secondary
# secondary
# secondary
# footway
# footway
# trunk_link
# residential
#
# secondary
#
# tertiary
# secondary
# residential
# secondary
# secondary
# residential
# residential
# footway
# service
# residential
# service
# residential
# residential
# path
# residential
# unclassified
# service
# unclassified
# unclassified
# unclassified
# unclassified
# service
# unclassified
# unclassified
# service
# secondary
# unclassified
# secondary
# service
# secondary
# secondary
# unclassified
# secondary
# secondary
# secondary
# service
# secondary
# residential
# tertiary
# secondary
# secondary
# secondary
# secondary
# footway
# footway
# secondary
# secondary
# service
# secondary
# secondary
# footway
# footway
# secondary
# secondary
# secondary
# secondary
# footway
# footway
# tertiary
# footway
# footway
# tertiary
# service
# tertiary
# tertiary
# unclassified
# tertiary
# tertiary
# tertiary
# tertiary
# service
# service
# tertiary
# tertiary
# service
# tertiary
# tertiary
# service
# tertiary
# service
# secondary
# secondary
# residential
# secondary
# residential
# secondary
# secondary
# secondary
# service
# secondary
# secondary
# residential
# secondary
# secondary
# residential
# tertiary
# tertiary
# residential
# footway
# tertiary
# tertiary
# service
# tertiary
# service
# tertiary
# trunk
# residential
# residential
# unclassified
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# service
# tertiary
# tertiary
# footway
# footway
# tertiary
# residential
# residential
# tertiary
# primary
# tertiary
# tertiary
# primary
# tertiary
# tertiary
# service
# tertiary
# tertiary
# service
# tertiary
# cycleway
# tertiary
# service
# tertiary_link
# tertiary
# tertiary
# living_street
# tertiary
# tertiary
# residential
# tertiary
# tertiary
# tertiary
# service
# tertiary
# tertiary
# tertiary
# footway
# footway
# secondary
# secondary
# tertiary
# motorway_link
# motorway
# motorway
# motorway
# motorway_link
# motorway
# motorway_link
# motorway_link
#
#
#
#
#
#
# motorway_link
# motorway
#
#
#
#
# motorway
# motorway
#
#
#
# motorway
#
# motorway
#
#
#
#
# motorway
# motorway
#
#
#
#
# motorway
# motorway_link
# motorway
#
#
# motorway
#
#
# motorway_link
#
#
#
#
# motorway_link
#
#
#
#
#
#
#
#
#
# secondary
#
# primary
# service
# residential
# residential, primary
# primary
# path
# primary
# primary
# primary
# primary
# tertiary
# trunk
# trunk_link
# trunk
# trunk
#
#
# trunk_link
# trunk
# trunk_link
# motorway_link
# trunk_link
# motorway_link
# motorway_link
# motorway_link
# residential
# residential
# residential
# residential
# residential
# service
# secondary
# service
# secondary
# primary_link
# secondary
# primary
# secondary
# secondary
# residential
# secondary
#
# trunk_link
#
# trunk_link
# primary_link
# primary
# service
# primary
#
#
# trunk
#
#
# trunk
#
#
# trunk
# trunk
#
#
# trunk
# trunk
#
# trunk_link
# trunk_link
# trunk, primary
# service
# primary
# residential
# primary
# primary
# footway
# footway
# service
# primary
# primary
#
#
# primary
#
#
# primary
# secondary_link
# primary
# primary
# secondary_link
# motorway
#
#
#
# motorway
#
# motorway
# motorway_link
# motorway_link
# motorway
# footway
# motorway_link
# footway
# motorway
# motorway
# motorway
#
#
#
# motorway, primary
#
# primary_link
# primary
# primary
# primary
# primary
# primary
#
#
#
#
#
#
# primary
# residential
# primary
# residential
# primary
# residential
# primary
# trunk_link
#
#
# trunk
#
#
# trunk
#
# trunk
#
#
#
# trunk
#
#
# trunk
# trunk
#
#
# trunk
#
#
# trunk
#
#
# trunk
#
#
# trunk
# trunk
#
#
# trunk
# trunk_link
# trunk
#
# secondary
# secondary
# motorway_link
# trunk
# trunk_link
# trunk
#
# trunk
#
#
#
#
# trunk
#
#
#
#
# trunk
#
# trunk
#
#
# trunk_link
# secondary
# secondary
# trunk_link
# secondary
# secondary
# secondary
# secondary
# secondary
# living_street
# secondary
# secondary
# secondary
# secondary
# secondary
# footway
# footway
# secondary
# footway
# footway
# footway
# secondary
# secondary
# secondary
# secondary
# service
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# footway
# secondary
# secondary
# residential
# secondary
# secondary
# residential
# secondary
# secondary
# service
# residential
# cycleway
# secondary
# secondary
# service
#
#
# service
# living_street
# living_street
# service
# secondary
# service
# secondary
# secondary
# service
# secondary
# secondary
# secondary
# secondary
# service
# secondary
# secondary
# secondary
# service
# secondary
# service
# service
# secondary
# secondary
# secondary
# footway
# footway
# secondary
# secondary
# secondary
# tertiary
# secondary
# secondary
# secondary
# tertiary
# secondary
# secondary
# footway
# footway
# secondary
# secondary
# path
#
#
# tertiary
#
#
# secondary
#
#
# residential
# secondary
# residential
# secondary
# secondary
# secondary
# secondary
# secondary
# residential
# secondary
# secondary
# service
# residential
# residential
# residential
# residential
# unclassified
# residential
# service
# residential
# residential
# residential
# secondary
# residential
# secondary
# secondary
# secondary
# footway
# footway
# secondary
# secondary
# secondary
# secondary
# unclassified
# secondary
# secondary
# unclassified
#
#
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary_link
# footway
# footway
# trunk_link
# footway
# footway
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
#
#
# secondary
# secondary
# service
# secondary
# secondary
# secondary
# trunk_link
# secondary
# track
# unclassified
# tertiary
# tertiary
# footway
# footway
# tertiary
# tertiary
# tertiary
# service
# track
# tertiary
# service
# tertiary
# tertiary
# residential
# tertiary
# tertiary
# tertiary
# footway
# footway
# tertiary
# tertiary
# tertiary
# path
# path
# secondary
# service
# secondary
# footway
# footway
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# service
# tertiary
# tertiary
# residential
# secondary
# tertiary
# tertiary
# footway
# footway
#
# tertiary
#
#
#
# residential
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
#
# tertiary
#
#
# tertiary
#
# secondary
# secondary
# tertiary
# secondary
# residential
#
# tertiary
#
# tertiary
# tertiary
#
# tertiary
#
# tertiary
# tertiary
# tertiary
#
#
#
# tertiary
#
# service
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
#
#
# tertiary
#
#
# tertiary
# tertiary
# service
# secondary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
# tertiary
# service
#
# tertiary
#
# tertiary
#
#
#
#
#
#
#
# residential
# tertiary
# secondary
#
#
# secondary
# residential
# tertiary
# tertiary
# tertiary
# footway
# footway
# tertiary
# residential
# secondary
# secondary
#
# tertiary
#
#
# tertiary
#
# secondary
# secondary
# tertiary
# tertiary
#
#
# tertiary
#
#
# secondary
# service
# secondary
#
# secondary
#
# secondary
# track
#
# tertiary
#
# tertiary
#
#
#
# tertiary
#
# tertiary
# service
# residential
# residential
# secondary
# service
# tertiary
# tertiary
#
#
# service
# tertiary
#
#
# tertiary
#
#
# residential
# tertiary
# tertiary
#
# tertiary
#
#
# tertiary
#
# trunk_link
# steps
# tertiary
# tertiary
# secondary_link
# secondary
# tertiary
# service
# tertiary
# track
# tertiary
# service
# tertiary
# service
# tertiary
# tertiary
# secondary
# secondary
# tertiary
# residential
# tertiary
# tertiary
# residential
# tertiary
# path
# tertiary
# tertiary
# tertiary
# tertiary
# service
# tertiary
# tertiary
# residential
# secondary
# service
# tertiary
#
#
# tertiary
#
#
#
# tertiary
#
# tertiary
# secondary
# service
# secondary
# tertiary
#
#
# tertiary
#
#
# residential
# tertiary
# tertiary
#
# tertiary
#
#
# tertiary
#
# residential
# tertiary
# tertiary
# path
# tertiary
# tertiary
# unclassified
# secondary
# secondary
# service
# secondary
# secondary
# residential
# tertiary
#
#
#
#
# tertiary
# secondary
#
#
# tertiary
# tertiary
# service
# tertiary
# path
# tertiary
# service
# secondary
# secondary
#
# tertiary
#
#
# tertiary
#
# secondary
#
#
# secondary
# tertiary
# tertiary
# footway
# footway
# tertiary
# service
# tertiary
# residential
# tertiary
# tertiary
# tertiary
# footway
# footway
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
# service
# service
# tertiary
# tertiary
# service
#
# secondary
#
# secondary
# footway
# secondary
# secondary
# residential
# secondary
# secondary
# service
# secondary
# secondary
# trunk_link
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary_link
# secondary
# unclassified
# secondary
# secondary
# secondary
# secondary
# secondary
# unclassified
# secondary
# secondary
# secondary
# unclassified
# secondary
# secondary
# trunk_link
# trunk_link
#
#
# trunk_link
#
# trunk_link
#
# trunk_link
# secondary
# secondary_link
# secondary
# service
# tertiary
# tertiary
# residential
# tertiary
# tertiary
# tertiary
# tertiary
# footway
# tertiary
# service
# secondary
# secondary
# tertiary
# residential
# residential
# secondary
# secondary
# service
# tertiary
# tertiary
# residential
# tertiary
# tertiary
# residential
# residential
# service, footway
# residential
# residential
# footway
# residential
# residential
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# tertiary
# tertiary
# motorway_link
# motorway
# motorway
#
#
#
# motorway
#
# motorway
#
#
#
#
# motorway
# unclassified
# secondary
# tertiary
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# service
# residential
# residential
# residential
# residential
# residential
# residential
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# track
#
#
#
# service
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# motorway
#
#
#
#
# motorway
# motorway
#
#
#
#
# motorway
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# service
# tertiary
# footway
# tertiary
# residential
# residential
# residential
# residential
# service
# residential
# residential
# service
# residential
# service
# residential
# service
# service
# service
# service
# footway
# residential
# residential
# residential
# service
# residential
# service
# residential
# residential
# residential
# residential
# residential
# secondary
# secondary
# secondary_link
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
# path
# tertiary
# service
# tertiary
# tertiary
# tertiary
# primary_link
# tertiary_link
# footway
# footway
# secondary
# secondary
# secondary
# secondary_link
# secondary
# secondary
# secondary
# secondary
#
#
#
#
# residential
# residential
# residential
# residential, path
# residential
# residential
# residential
# residential
# footway
# footway
# residential
# residential
# residential
# residential
# residential, footway
# residential
# secondary
# secondary
# track
# service
# service
# secondary
#
# secondary
#
# track
# service
# track
# path
# track, path
# path
# path
# path
# path
# path
# residential
# residential
# path, footway
# residential
# residential
# track
# residential
#
#
#
#
# residential
#
#
#
#
#
#
#
#
# path
# path
# path
# motorway_link
# motorway
# motorway
# service
#
# secondary
# secondary
# residential
# secondary
# residential
# secondary
# residential
# secondary
# residential
# secondary
# residential
# secondary
# tertiary
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# track
# secondary
# secondary
# unclassified
# secondary
# secondary
# unclassified
# unclassified
# service
# unclassified
# footway
# unclassified
# service
# unclassified
# secondary
# secondary
# residential
# secondary
# residential
# secondary
# secondary
# secondary
# residential
# secondary
# residential
# secondary
# secondary
# secondary
# service
# secondary
# secondary
# residential
# trunk
#
#
#
#
# trunk
# trunk
# trunk_link
# trunk
# trunk_link
# trunk_link
# trunk_link
# trunk_link
# trunk_link
# secondary
# secondary
# residential
# tertiary
# tertiary
# residential
# residential
# residential
# living_street
# residential
# residential
# tertiary
# secondary
#
# secondary
# footway
# tertiary
# tertiary
#
#
# primary
# primary
# primary
# footway
# footway
# primary
# primary
# secondary
# secondary
# primary
# secondary
# secondary
# service
# service
# primary
# primary
#
#
# motorway
# motorway_link
# motorway
#
#
# motorway
# motorway_link
# motorway_link
# motorway_link
#
#
# motorway_link
#
#
# motorway
# motorway
#
#
# motorway
# trunk_link
# trunk
# track
# secondary
# secondary
# service
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# unclassified
# unclassified
# service
# unclassified
# unclassified
# service
# service
# service
# service
# service
# service
# service
# service
# unclassified
# unclassified
# secondary
# residential
# secondary
# residential
# track
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# tertiary
# tertiary
# service, unclassified
# tertiary
# tertiary
# footway
# tertiary
# tertiary
# residential
# tertiary
# tertiary
# secondary
# secondary
# tertiary
# service
# path
# service
# service
# service
# track
# track
# residential
# living_street
# residential
# residential
# residential
# residential
# track, residential
# track
# track
# unclassified
# unclassified
# track
# residential
# secondary
# secondary
# residential
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# service
# residential
# residential
# residential
# residential
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# secondary
# secondary
# service
# secondary
# secondary
# service
# secondary
# secondary
# secondary
# secondary
# service
# secondary
# secondary
# secondary
# living_street
# residential
# residential
# residential
# service
# service
# residential
# residential
# path
# footway
# tertiary
# tertiary
# residential
# residential
# footway
# residential
# footway
# service
# residential
# unclassified
# residential
# residential
# residential
# footway
# service
# unclassified
# unclassified
# service
# unclassified
# service
# track
# service
# service, residential
# track
# residential
# residential
# residential
# footway
# residential
# residential
# residential
# footway
# path
# footway
# footway
# footway
# footway
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# footway
# footway
# secondary
# residential
# secondary
# secondary
# secondary
# track
# secondary
# secondary
# residential
# secondary
# residential
# secondary
# secondary
# secondary
# secondary
# residential
# footway
# footway
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# residential
# secondary
# secondary
# residential
# secondary
# residential
# secondary
# residential
# secondary
# secondary
# secondary
# secondary
# path
# footway
# cycleway
# path
# unclassified
#
#
# unclassified
# cycleway
# unclassified
# cycleway
# unclassified
# residential, unclassified
# unclassified
# cycleway
# residential
# residential, unclassified
# residential
#
# unclassified
#
#
#
# unclassified
#
# unclassified
#
# residential
#
# residential
#
# residential
#
# residential
#
# residential
#
# residential
#
#
# residential
#
# residential
#
# unclassified
# tertiary
# tertiary
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# residential
# tertiary
# tertiary
#
#
# motorway_link
# motorway_link
# motorway_link
# motorway_link
# motorway_link
# primary
# primary
# primary
# primary
# primary
# primary
# tertiary
# cycleway, footway
# cycleway, path
# tertiary
# secondary
# secondary
# service
# residential
# secondary
# secondary
# tertiary
# secondary
# primary
# primary
# secondary
# primary
# tertiary
# tertiary
# residential
# primary
# primary
# primary_link
# path
# primary_link
# path
# footway
# residential
# footway
# footway
# residential
# residential
# residential
# residential
# residential
# residential
# footway
# footway
# residential
# unclassified
# residential
# pedestrian
# unclassified
# residential
# primary
# primary
# footway
# footway
# primary
# primary
# primary
# primary_link
# residential
# residential
# footway
# residential
# residential
# residential
# residential
# tertiary
# tertiary
# residential
# tertiary
# tertiary
# residential
# secondary
# residential
# secondary
# secondary
# residential
# secondary
# secondary
# residential
# secondary
# residential
# residential
# secondary
# secondary
# residential
# unclassified
# secondary
# secondary
# secondary
#
#
# residential
# residential
# steps, footway
# residential
# residential
# residential
# track
# residential, unclassified
# unclassified
# tertiary
# tertiary
# residential
# residential
# residential
# service, path
# residential
# residential
# service
# residential
# residential
# service
# residential
# secondary
# secondary
# residential
# residential
# residential
# residential
# secondary
# residential
# service
# motorway_link
# secondary
#
#
# secondary
# secondary
#
#
# secondary
# secondary
# secondary
# footway
# footway
# secondary
# secondary
# service
# secondary
# residential
# service
# secondary
# residential
# residential
# residential
# unclassified
# unclassified
# footway
# track
# unclassified
# unclassified
# tertiary
# residential
# tertiary
# residential
# secondary
# secondary
# residential
# residential
# residential
# residential
# residential
# residential
#
# trunk_link
#
#
# trunk_link
#
# trunk_link
# motorway_link
# motorway_link
# motorway_link
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# motorway
#
#
# motorway
#
#
# motorway
#
#
# trunk_link
# trunk_link
# motorway_link
# trunk_link
# trunk_link
# residential
# residential
# residential
# residential
# residential
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential, footway
# unclassified
# residential
# residential
# residential
# residential
# residential, footway
# residential
# trunk
#
#
#
# trunk_link
#
#
#
# trunk_link
# trunk
# motorway_link
# trunk
# trunk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tertiary
# residential
# tertiary
# secondary
# trunk_link
#
# unclassified
# unclassified
#
#
#
#
#
#
#
#
#
#
#
#
#
# secondary
#
#
# secondary
# unclassified
# unclassified
# track
# track
# track
# secondary
# service
# secondary
# track
# track
# track
# track
# track
# track
#
# track
#
#
# residential
#
#
#
# residential
#
#
# residential
#
#
# unclassified
#
#
# unclassified
#
#
# tertiary
#
#
# tertiary
#
#
# service
# motorway_link
# motorway_link
# motorway_link
# trunk
#
#
#
# trunk
#
#
#
# trunk
# trunk
# secondary
# secondary
# residential
# residential
# residential
# service
# residential
# residential
# service
# service
# footway
# residential
# residential
# service
# path
# residential
# residential
# residential
# living_street
# living_street
# footway
# living_street
# footway
# living_street
# living_street
# living_street
# living_street
# living_street
# living_street
# living_street, footway
# living_street
# living_street
# living_street
# footway
# living_street
# living_street, footway
# living_street
# footway
# secondary
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# footway
# residential
# residential
# footway
# residential
# residential
# footway
# service
# residential
# service
# motorway
#
#
#
#
# motorway
# motorway
#
#
#
#
# motorway
# primary
# tertiary
# tertiary
# tertiary
# tertiary
# primary
# tertiary
# unclassified
# residential
# residential
# service
# footway
# residential
# residential
# footway
# residential
# residential
# residential
# residential, path
# residential
# residential
# residential
# residential
# residential
# track
# residential
# path
# residential
# residential
# residential
# residential
# residential
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential, footway
# residential
# residential
# residential
# residential
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential, footway
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# path
# residential
# residential
# residential, footway
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# service
# residential
# residential
# residential
# residential
# residential
# residential
# service, residential
# residential
# residential
# residential
# footway
# residential
# residential
# residential
# unclassified
# residential, path
# tertiary
# tertiary
# unclassified
# tertiary
# residential
# tertiary
# tertiary
#
# tertiary
#
# tertiary
# tertiary
#
# tertiary
#
# unclassified
# trunk_link
# motorway_link
# motorway_link
#
# motorway_link
#
# trunk_link
# motorway_link
# motorway_link
#
#
# motorway_link
# motorway_link
#
#
# motorway
# motorway
#
#
# service
# secondary
# secondary
# service
# service
# service
# residential
# unclassified
# residential
# service
# residential
# residential
# residential
# residential
# residential
# footway
# residential
# residential
# service
# unclassified
# residential
# unclassified
# residential
# residential, path
# residential
# motorway_link
# motorway_link
# trunk
#
#
# trunk
#
#
# trunk
#
#
# trunk_link
# trunk
# unclassified
# unclassified
# service
# unclassified
# unclassified
# service
# unclassified
# service
# unclassified
# unclassified
# service
# unclassified
# unclassified
# unclassified
# unclassified
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
#
#
# tertiary
# living_street
#
#
# tertiary
#
#
# tertiary
# steps, footway
# service
# service
# service
# service, steps, footway
# service
#
#
#
#
# service
# unclassified
# residential
# residential
# service, footway
# residential, unclassified
# residential
# service
# service
# unclassified
# unclassified
# unclassified
# residential
# residential
# residential
# residential
# residential
# secondary
# secondary
# primary
# secondary
# residential
# primary
# residential
# residential
#
#
#
#
#
#
#
#
# secondary
# primary
#
# primary
#
#
# primary
#
# secondary_link
# primary
# secondary
# footway
# footway
# secondary
# residential
# cycleway, residential
# secondary
# path
# cycleway
# residential, path
# footway
# service
# service
# tertiary
# primary
# tertiary
# primary
#
#
#
#
# secondary
# secondary
# secondary
#
#
# secondary
# tertiary
# footway
# footway
# tertiary
# tertiary
# unclassified
# residential
# cycleway, path
# cycleway, path
# secondary
# tertiary
# service
# tertiary
# tertiary
# tertiary
# tertiary
# tertiary
# unclassified
# tertiary
# tertiary
# primary
# residential
# primary
# residential
# primary
# primary
# tertiary
# primary
# footway
# primary
# unclassified
# unclassified
# service
# service
# tertiary
#
# tertiary
#
# tertiary
#
# tertiary
#
# residential
# tertiary
# residential
# tertiary
# residential
# residential
#
#
#
# residential
# residential
#
# residential
#
#
# residential
# residential
# residential
#
# residential
#
# residential
#
# residential
#
# residential
#
# residential
#
# residential
#
#
# residential
# residential
# residential
# path
# residential
# residential
# residential
# residential
# residential
# service
# living_street
# living_street
# service
# primary
# residential
# primary
#
#
#
#
# residential
#
#
# residential
# primary
# primary
#
#
# path
# path
# path
# primary
# footway
# footway
# primary
# footway
#
#
# primary
#
#
# primary
#
#
# primary
# footway
#
#
# primary
#
#
# primary
#
#
# primary
#
#
# primary
#
#
# primary
# footway
#
#
# primary
# primary
# tertiary
#
#
# primary
#
#
# primary
# primary
#
#
# primary
#
#
# tertiary
# tertiary
#
# trunk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# secondary
# primary
# primary
# footway
# footway
# footway
# track
# secondary
# secondary
# secondary
# secondary
# secondary
# secondary
# path, footway
# secondary
# service
# secondary
# secondary
# secondary
# service
# secondary
# path
# secondary
#
# service
# secondary
# secondary
# secondary
# secondary
# service
#
# secondary
#
# secondary
# track
# path
# secondary
# secondary
#
# secondary
# secondary
# service
# secondary
# secondary
# secondary
# secondary
# secondary
# service
# service
# service
# service
# secondary
# secondary
# residential
# residential
# residential
# service
# residential
# residential
# residential
# secondary
# secondary
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# residential
# secondary
# secondary
# secondary
# secondary
# residential
# secondary
# cycleway
# unclassified
# secondary
# secondary
# secondary
# secondary
# trunk_link
# secondary
#
# secondary
# secondary
#
# secondary
#
# secondary
#
# secondary
# secondary
#
#
# footway
# secondary
#
# secondary
#
# residential
# secondary
#
# secondary
#
# secondary
#
# secondary
#
# secondary
#
# secondary
#
#
# secondary
#
# secondary
# tertiary
# secondary
#
# secondary
#
# secondary
#
#
# secondary
# residential
#
#
# residential
#
#
# residential
# residential
# residential
#
# residential
#
# residential
# residential
# cycleway, service
# residential
# residential
# service
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# tertiary
# residential
# tertiary
# residential
# service
# residential
# service
# residential
# service
# living_street
# residential
# residential
# living_street
# living_street
# footway
# living_street
# living_street
# living_street
# living_street
# living_street
# residential
# residential
# residential
# residential
# service
# residential
# residential
# service
# residential
# secondary
# secondary
# track
# footway
# track
# footway
# footway
# footway
# track
# track, footway
# service
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# footway
#
#
# service
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# path
# residential
# residential
# residential
#
#
#
# residential
#
# path
# path
# path
# path
# path
# path, footway
# path
# path
# path
# path
# living_street
# living_street
# living_street
#
#
# residential
#
# residential
#
# secondary
# residential
# residential
# residential
# residential
# secondary
# residential
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tertiary
# residential
# tertiary
# residential
# service
#
#
# residential
# residential
# residential
# service
# tertiary
# service
# tertiary
# service
#
#
# service
# service
#
#
# service
# service
# service
# service
# service
# tertiary
# tertiary
# unclassified
# unclassified
# service
# unclassified
# residential
# unclassified
# service
# unclassified
# service
# unclassified
# path
# unclassified
# residential
# unclassified
# steps, footway
# residential
# residential
# footway
# steps, footway
# residential
# secondary_link
# secondary_link
# service
# footway
# service
# path
# service
# service
# footway
# footway
# footway
# footway
# footway
# track
# track
# track
# track
# residential
# residential
# service
# residential
# residential
# footway
# residential
# residential
# footway
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential
# residential, path
# residential
# residential
# residential
# secondary
# secondary
# living_street
# residential
# residential
# living_street
# living_street
# track, living_street
# living_street
# path, living_street
# living_street
# residential
# residential
# footway
# residential
# footway
# residential
# footway
# cycleway
# cycleway, residential
# service
# service
# footway
# service, track
# service
# service
# track
# track, service
# track
# track
# track
# footway
# track
# track, footway
# track
# footway
# footway
# service, residential
# footway
# footway
# track
# residential
# footway
# residential
# track
# path
# path
# track
#
#
#
# track
#
# track
#
# track
#
#
# track
#
#
# track
#
#
# service
#
# service
# residential
# secondary
# secondary
# residential
# service
# footway
# service
# service
# service
#
# service
#
#
# service
#
#
# service
#
#
# service
#
#
# service
#
#
# service
#
# service
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# track
# residential
# residential
# track
#
#
#
#
# track
#
#
# track
#
#
# track
#
#
# track
#
#
# secondary
# service
# secondary
# track, residential
# residential
# residential
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 174
#     169     if not check_ids_exist(cursor, source_node_id, edge_id, "IncidentEdges"):
#     170         cursor.execute('''
#     171             INSERT INTO IncidentEdges (NodeId, edgeId)
#     172             VALUES (?, ?)
#     173         ''', (source_node_id, edge_id))
# --> 174     if not check_ids_exist(cursor, target_node_id, edge_id, "IncidentEdges"):
#     175         cursor.execute('''
#     176             INSERT INTO IncidentEdges (NodeId, edgeId)
#     177             VALUES (?, ?)
#     178         ''', (target_node_id, edge_id))
#     179 conn.commit()
#
# Cell In[9], line 55, in check_ids_exist(cursor, id1, id2, table_name)
#      54 def check_ids_exist(cursor, id1, id2, table_name):
# ---> 55     cursor.execute("SELECT COUNT(*) FROM " + table_name + " WHERE NodeId = ? AND EdgeId = ?", (id1, id2))
#      56     count = cursor.fetchone()[0]
#      57     return count > 0
#
# KeyboardInterrupt:
